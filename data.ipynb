# %%
import streamlit as st
import numpy as np
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
df = pd.read_csv("india.csv")
df.sample(5)
# Out:
#                  State   District   Latitude  Longitude  District code  \
# 327           Nagaland   Tuensang  26.211045  94.858099            267
# 292        Maharashtra  Ratnagiri  17.210195  73.257259            528
# 491      Uttar Pradesh  Sonbhadra  24.466933  83.068163            200
# 318            Mizoram    Lunglei  23.007717  92.635126            286
# 168  Jammu and Kashmir   Udhampur  33.047707  75.152870             19
#
#      Population    Male  Female  Literate  Male_Literate  ...  \
# 327      196596  101933   94663    117511          63653  ...
# 292     1615069  761121  853948   1199392         619012  ...
# 491     1862559  971344  891215    985708         601988  ...
# 318      161428   82891   78537    121122          64515  ...
# 168      554985  296784  258201    322354         197543  ...
#
#      Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 327                             23                              2
# ...

# %%
df.columns[:].str.replace("_"," " )
# Out:
# Index(['State', 'District', 'Latitude', 'Longitude', 'District code',
#        'Population', 'Male', 'Female', 'Literate', 'Male Literate',
#        ...
#        'Power Parity Rs 150000 240000', 'Power Parity Rs 240000 330000',
#        'Power Parity Rs 150000 330000', 'Power Parity Rs 330000 425000',
#        'Power Parity Rs 425000 545000', 'Power Parity Rs 330000 545000',
#        'Power Parity Above Rs 545000', 'Total Power Parity', 'Sex ratio',
#        'Literacy rate'],
#       dtype='object', length=122)

# %%
for i in range(len(df.columns[:])):
    df.rename(columns={df.columns[i]: df.columns[i].replace("_", " ")}, inplace=True)

# %%
df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Male Literate  ...  \
# ...

# %%
State_List = list(df['State'].unique())
State_List.insert(0, "Overall India")

# %%
State_List
# Out:
# ['Overall India',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Daman and Diu',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttaranchal',
#  'West Bengal']

# %%
sorted(df.columns[:])
# Out:
# ['Age Group 0 to 29',
#  'Age Group 30 to 49',
#  'Age Group above 50',
#  'Age not stated',
#  'Agricultural Workers',
#  'Below Primary Education',
#  'Buddhists',
#  'Christians',
#  'Condition of occupied census houses Dilapidated Households',
#  'Cultivator Workers',
#  'District',
#  'District code',
#  'Female',
#  'Female Literate',
#  'Female SC',
#  'Female ST',
#  'Female Workers',
#  'Graduate Education',
#  'Having bathing facility Total Households',
#  'Having latrine facility within the premises Total Households',
#  'Higher Education',
#  'Hindus',
#  'Household Workers',
#  'Household size 1 person Households',
#  'Household size 1 to 2 persons',
#  'Household size 2 persons Households',
#  'Household size 3 persons Households',
#  'Household size 3 to 5 persons Households',
#  'Household size 4 persons Households',
#  'Household size 5 persons Households',
#  'Household size 6 8 persons Households',
#  'Household size 9 persons and above Households',
# ...

# %%
df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Male_Literate  ...  \
# ...

# %%
import plotly.express as px

fig = px.scatter_mapbox(df, lat="Latitude", lon="Longitude",size="Age Group 0 to 29",color="Female SC",
                    zoom=3,mapbox_style="carto-positron",size_max=10, # Set initial zoom level
    width=1000,  # Adjust width to your preference
    height=600 )
fig.update_layout(
    
    mapbox_center=dict(lat=df['Latitude'].mean(), lon=df['Longitude'].mean()),  # Center map
     # Adjust height to your preference
)

fig.show()
